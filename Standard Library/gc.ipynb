# %% [markdown]
# ## gc - Garbage Collector interface
# This module provides an interface to the optional garbage collector. It provides the ability to disable the collector, tune the collection frequency, and set debugging options. It also provides access to unreachable objects that the collector found but cannot free. Since the collector supplements the reference counting already used in Python, you can disable the collector if you are sure your program does not create reference cycles. Automatic collection can be disabled by calling gc.disable(). To debug a leaking program call gc.set_debug(gc.DEBUG_LEAK). Notice that this includes gc.DEBUG_SAVEALL, causing garbage-collected objects to be saved in gc.garbage for inspection.

# %%
# Enable automatic garbage collection
import gc
gc.enable()

# %%
gc.disable()

# %%
gc.isenabled()
# Out:
# False

# %% [markdown]
# ## gc.collect(generation=2)
# With no arguments, run a full collection. The optional argument generation may be an integer specifying which generation to collect (from 0 to 2). A ValueError is raised if the generation number is invalid. The number of unreachable objects found is returned.
#
# The free lists maintained for a number of built-in types are cleared whenever a full collection or collection of the highest generation (2) is run. Not all items in some free lists may be freed due to the particular implementation, in particular float.

# %%
gc.collect(generation=2)
# Out:
# 15

# %%
# Set the garbage collection debugging flags. Debugging information will be written to sys.stderr. 
# See below for a list of debugging flags which can be combined using bit operations to control debugging.
gc.set_debug(flags)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-3a633c493041> in <module>
#       1 # Set the garbage collection debugging flags. Debugging information will be written to sys.stderr.
#       2 # See below for a list of debugging flags which can be combined using bit operations to control debugging.
# ----> 3 gc.set_debug(flags)
#
# NameError: name 'flags' is not defined

# %%
# Return the debugging flags currently set.
gc.get_debug()
# Out:
# 0

# %%
# Returns a list of all objects tracked by the collector, excluding the list returned. 
# If generation is not None, return only the objects tracked by the collector that are in that generation.
gc.get_objects(generation=None)
# Out:
# [deque([]),
#  {'_cond': <Condition(<unlocked _thread.lock object at 0x000001FA086A1060>, 0)>,
#   '_flag': True},
#  <bound method Thread._bootstrap of <GarbageCollectorThread(Thread-6, started daemon 15644)>>,
#  <weakref at 0x000001FA0867D6D0; to '_thread.lock' at 0x000001FA086D14B0>,
#  <zmq.sugar.context.Context at 0x1fa0867def0>,
#  {'_shadow': False,
#   'sockopts': {},
#   '_sockets': {<weakref at 0x000001FA08656F90; to 'Socket' at 0x000001FA0869F820>, <weakref at 0x000001FA08656630; to 'Socket' at 0x000001FA0869F7C0>}},
#  {<weakref at 0x000001FA08656F90; to 'Socket' at 0x000001FA0869F820>, <weakref at 0x000001FA08656630; to 'Socket' at 0x000001FA0869F7C0>},
#  {<weakref at 0x000001FA08656630; to 'Socket' at 0x000001FA0869F7C0>,
#   <weakref at 0x000001FA08656F90; to 'Socket' at 0x000001FA0869F820>},
#  {'data': {<weakref at 0x000001FA08656630; to 'Socket' at 0x000001FA0869F7C0>,
#    <weakref at 0x000001FA08656F90; to 'Socket' at 0x000001FA0869F820>},
#   '_remove': <function _weakrefset.WeakSet.__init__.<locals>._remove(item, selfref=<weakref at 0x000001FA0867D900; to 'WeakSet' at 0x000001FA086D1460>)>,
#   '_pending_removals': [],
#   '_iterating': set()},
#  <weakref at 0x000001FA0867D900; to 'WeakSet' at 0x000001FA086D1460>,
#  (<weakref at 0x000001FA0867D900; to 'WeakSet' at 0x000001FA086D1460>,),
#  <function _weakrefset.WeakSet.__init__.<locals>._remove(item, selfref=<weakref at 0x000001FA0867D900; to 'WeakSet' at 0x000001FA086D1460>)>,
#  [],
#  set(),
#  <zmq.sugar.socket.Socket at 0x1fa0869f820>,
#  <weakref at 0x000001FA08656F90; to 'Socket' at 0x000001FA0869F820>,
#  {},
#  <zmq.sugar.socket.Socket at 0x1fa0869f7c0>,
#  <weakref at 0x000001FA08656630; to 'Socket' at 0x000001FA0869F7C0>,
#  <bound method Socket.recv of <zmq.sugar.socket.Socket object at 0x000001FA0869F820>>,
#  (<zmq.sugar.socket.Socket at 0x1fa0869f820>,),
#  {'status': 'ok', 'execution_count': 2, 'user_expressions': {}, 'payload': []},
#  [],
#  {'header': {'msg_id': '4f0d31c9-57faaa7b68eec10de22bcc16_17',
#    'msg_type': 'execute_reply',
#    'username': 'username',
#    'session': '4f0d31c9-57faaa7b68eec10de22bcc16',
#    'date': datetime.datetime(2021, 1, 20, 21, 35, 8, 956268, tzinfo=datetime.timezone.utc),
#    'version': '5.3'},
#   'msg_id': '4f0d31c9-57faaa7b68eec10de22bcc16_17',
#   'msg_type': 'execute_reply',
#   'parent_header': {'msg_id': '0a045740d0854f768ff9559b0025f6df',
#    'username': 'username',
#    'session': '45c6e213fb1b4b528fc52742791acad0',
#    'msg_type': 'execute_request',
#    'version': '5.2',
#    'date': datetime.datetime(2021, 1, 20, 21, 35, 8, 863530, tzinfo=datetime.timezone.utc)},
#   'content': {'status': 'ok',
#    'execution_count': 2,
#    'user_expressions': {},
#    'payload': []},
#   'metadata': {'started': datetime.datetime(2021, 1, 20, 21, 35, 8, 864529, tzinfo=datetime.timezone.utc),
#    'dependencies_met': True,
#    'engine': '0b091999-8b54-4c74-8a2b-412ad341b312',
#    'status': 'ok'},
#   'tracker': <zmq.sugar.tracker.MessageTracker at 0x1fa08456160>},
#  <tornado.gen.Runner at 0x1fa086d13d0>,
#  {'ctx_run': <function Context.run>,
#   'gen': <generator object Kernel.dispatch_shell at 0x000001FA085E7B30>,
#   'result_future': None,
#   'future': <tornado.gen._NullFuture at 0x1fa08428b80>,
#   'running': False,
#   'finished': True,
#   'io_loop': <tornado.platform.asyncio.AsyncIOMainLoop at 0x1fa086012b0>},
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback at 0x1fa08638040>,
#  <frame at 0x000001FA07FF7AE0, file 'c:\\users\\subhadeep banerjee\\appdata\\local\\programs\\python\\python38\\lib\\enum.py', line 662, code __new__>,
#  <traceback at 0x1fa08638880>,
#  <frame at 0x000001FA07F8FC10, file 'c:\\users\\subhadeep banerjee\\appdata\\local\\programs\\python\\python38\\lib\\enum.py', line 339, code __call__>,
#  <traceback at 0x1fa08638f00>,
#  <frame at 0x000001FA0866EA40, file 'c:\\users\\subhadeep banerjee\\appdata\\local\\programs\\python\\python38\\lib\\signal.py', line 32, code _int_to_enum>,
#  <frame at 0x000001FA0866B220, file 'c:\\users\\subhadeep banerjee\\appdata\\local\\programs\\python\\python38\\lib\\signal.py', line 48, code signal>,
#  <frame at 0x000001FA07F917B0, file 'c:\\users\\subhadeep banerjee\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\ipykernel\\kernelbase.py', line 288, code post_handler_hook>,
#  <_io.StringIO at 0x1fa086ced30>,
#  [],
#  <_io.StringIO at 0x1fa086cea60>,
#  [],
#  (<zmq.sugar.socket.Socket at 0x1fa08571f40>, 2),
#  [988],
#  [],
#  [],
#  (<zmq.sugar.socket.Socket at 0x1fa08571d00>, 1),
#  [],
#  [<socket.socket fd=960, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=0, laddr=('127.0.0.1', 53170), raddr=('127.0.0.1', 53171)>,
#   968,
#   988],
#  [],
#  <function asyncio.windows_events.IocpProactor.recv.<locals>.finish_recv(trans, key, ov)>,
#  <_OverlappedFuture pending overlapped=<completed, 0x1fa086cee50> cb=[BaseProactorEventLoop._loop_self_reading()]>,
#  (<_OverlappedFuture pending overlapped=<completed, 0x1fa086cee50> cb=[BaseProactorEventLoop._loop_self_reading()]>,
#   <_overlapped.Overlapped at 0x1fa086cee40>,
#   <socket.socket fd=744, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=0, laddr=('127.0.0.1', 53168), raddr=('127.0.0.1', 53169)>,
#   <function asyncio.windows_events.IocpProactor.recv.<locals>.finish_recv(trans, key, ov)>),
#  <bound method BaseProactorEventLoop._loop_self_reading of <ProactorEventLoop running=True closed=False debug=False>>,
#  <Context at 0x1fa086380c0>,
#  (740, 4294967295),
#  <cell at 0x000001FA0861A250: Runner object at 0x000001FA086D15B0>,
#  <Future pending cb=[coroutine.<locals>.wrapper.<locals>.<lambda>() at c:\users\subhadeep banerjee\appdata\local\programs\python\python38\lib\site-packages\tornado\gen.py:251, IOLoop.add_future.<locals>.<lambda>() at c:\users\subhadeep banerjee\appdata\local\programs\python\python38\lib\site-packages\tornado\ioloop.py:688]>,
#  <Context at 0x1fa08666380>,
#  <function Context.run>,
#  <generator object Kernel.process_one at 0x000001FA085E7F20>,
#  <frame at 0x000001FA07BBFEF0, file 'c:\\users\\subhadeep banerjee\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\ipykernel\\kernelbase.py', line 362, code process_one>,
#  <Future finished result=(10, 5, <bound method...01FA0857CE50>>, (<zmq.eventloo...001FA085A0100>, [<zmq.sugar.fr...001FA086C9A90>, <zmq.sugar.fr...001FA0869CA90>, <zmq.sugar.fr...001FA0869C880>, <zmq.sugar.fr...001FA086E9040>, <zmq.sugar.fr...001FA086E90F0>, <zmq.sugar.fr...001FA086E91A0>, ...]))>,
#  <tornado.gen.Runner at 0x1fa086d15b0>,
#  {'ctx_run': <function Context.run>,
#   'gen': <generator object Kernel.process_one at 0x000001FA085E7F20>,
#   'result_future': <Future pending cb=[coroutine.<locals>.wrapper.<locals>.<lambda>() at c:\users\subhadeep banerjee\appdata\local\programs\python\python38\lib\site-packages\tornado\gen.py:251, IOLoop.add_future.<locals>.<lambda>() at c:\users\subhadeep banerjee\appdata\local\programs\python\python38\lib\site-packages\tornado\ioloop.py:688]>,
#   'future': None,
#   'running': True,
#   'finished': False,
#   'io_loop': <tornado.platform.asyncio.AsyncIOMainLoop at 0x1fa086012b0>},
#  <cell at 0x000001FA086D10A0: Runner object at 0x000001FA086D15B0>,
#  {'f': typing.Any, 'return': None},
#  (<cell at 0x000001FA086D10A0: Runner object at 0x000001FA086D15B0>,),
#  <function tornado.gen.Runner.handle_yield.<locals>.inner(f: Any) -> None>,
#  <cell at 0x000001FA086D1100: function object at 0x000001FA086CE8B0>,
#  <cell at 0x000001FA086D16A0: _asyncio.Future object at 0x000001FA08657740>,
#  <cell at 0x000001FA086D1670: AsyncIOMainLoop object at 0x000001FA086012B0>,
#  (<cell at 0x000001FA086D1100: function object at 0x000001FA086CE8B0>,
#   <cell at 0x000001FA086D16A0: _asyncio.Future object at 0x000001FA08657740>,
#   <cell at 0x000001FA086D1670: AsyncIOMainLoop object at 0x000001FA086012B0>),
#  <function tornado.ioloop.IOLoop.add_future.<locals>.<lambda>(f)>,
#  <Context at 0x1fa08678b40>,
#  (<cell at 0x000001FA0861A250: Runner object at 0x000001FA086D15B0>,),
#  <function tornado.gen.coroutine.<locals>.wrapper.<locals>.<lambda>(_)>,
#  <Context at 0x1fa08628b80>,
#  <cell at 0x000001FA086D14F0: Runner object at 0x000001FA0863B910>,
#  {'f': typing.Any, 'return': None},
#  (<cell at 0x000001FA086D14F0: Runner object at 0x000001FA0863B910>,),
#  <function tornado.gen.Runner.handle_yield.<locals>.inner(f: Any) -> None>,
#  <cell at 0x000001FA086D1520: function object at 0x000001FA086CEC10>,
#  <cell at 0x000001FA086D1580: _asyncio.Future object at 0x000001FA08657640>,
#  <cell at 0x000001FA086D10D0: AsyncIOMainLoop object at 0x000001FA086012B0>,
#  (<cell at 0x000001FA086D1520: function object at 0x000001FA086CEC10>,
#   <cell at 0x000001FA086D1580: _asyncio.Future object at 0x000001FA08657640>,
#   <cell at 0x000001FA086D10D0: AsyncIOMainLoop object at 0x000001FA086012B0>),
#  <function tornado.ioloop.IOLoop.add_future.<locals>.<lambda>(f)>,
#  <Context at 0x1fa08654c00>,
#  (<function tornado.ioloop.IOLoop.add_future.<locals>.<lambda>(f)>,
#   <Context at 0x1fa08654c00>),
#  [(<function tornado.ioloop.IOLoop.add_future.<locals>.<lambda>(f)>,
#    <Context at 0x1fa08654c00>)],
#  [(3,
#    '# Returns a list of all objects tracked by the collector, excluding the list returned. \n# If generation is not None, return only the objects tracked by the collector that are in that generation.\ngc.get_objects(generation=None)',
#    '# Returns a list of all objects tracked by the collector, excluding the list returned. \n# If generation is not None, return only the objects tracked by the collector that are in that generation.\ngc.get_objects(generation=None)')],
#  [],
#  <bound method Condition.__exit__ of <Condition(<unlocked _thread.lock object at 0x000001FA08601780>, 0)>>,
#  [932],
#  [],
#  [],
#  <bound method Condition.__exit__ of <Condition(<unlocked _thread.RLock object owner=0 count=0 at 0x000001FA08601420>, 0)>>,
#  (1, 5236),
#  [],
#  <zmq.sugar.frame.Frame at 0x1fa086c9a90>,
#  [<zmq.sugar.frame.Frame at 0x1fa086c9a90>,
#   <zmq.sugar.frame.Frame at 0x1fa0869ca90>,
#   <zmq.sugar.frame.Frame at 0x1fa0869c880>,
#   <zmq.sugar.frame.Frame at 0x1fa086e9040>,
#   <zmq.sugar.frame.Frame at 0x1fa086e90f0>,
#   <zmq.sugar.frame.Frame at 0x1fa086e91a0>,
#   <zmq.sugar.frame.Frame at 0x1fa086e9250>],
#  <zmq.sugar.frame.Frame at 0x1fa0869ca90>,
#  <zmq.sugar.frame.Frame at 0x1fa0869c880>,
#  <zmq.sugar.frame.Frame at 0x1fa086e9040>,
#  <zmq.sugar.frame.Frame at 0x1fa086e90f0>,
#  <zmq.sugar.frame.Frame at 0x1fa086e91a0>,
#  <zmq.sugar.frame.Frame at 0x1fa086e9250>,
#  (<zmq.eventloop.zmqstream.ZMQStream at 0x1fa085a0100>,
#   [<zmq.sugar.frame.Frame at 0x1fa086c9a90>,
#    <zmq.sugar.frame.Frame at 0x1fa0869ca90>,
#    <zmq.sugar.frame.Frame at 0x1fa0869c880>,
#    <zmq.sugar.frame.Frame at 0x1fa086e9040>,
#    <zmq.sugar.frame.Frame at 0x1fa086e90f0>,
#    <zmq.sugar.frame.Frame at 0x1fa086e91a0>,
#    <zmq.sugar.frame.Frame at 0x1fa086e9250>]),
#  (10,
#   5,
#   <bound method Kernel.dispatch_shell of <ipykernel.ipkernel.IPythonKernel object at 0x000001FA0857CE50>>,
#   (<zmq.eventloop.zmqstream.ZMQStream at 0x1fa085a0100>,
#    [<zmq.sugar.frame.Frame at 0x1fa086c9a90>,
#     <zmq.sugar.frame.Frame at 0x1fa0869ca90>,
#     <zmq.sugar.frame.Frame at 0x1fa0869c880>,
#     <zmq.sugar.frame.Frame at 0x1fa086e9040>,
#     <zmq.sugar.frame.Frame at 0x1fa086e90f0>,
#     <zmq.sugar.frame.Frame at 0x1fa086e91a0>,
#     <zmq.sugar.frame.Frame at 0x1fa086e9250>])),
#  (<Future finished result=(10, 5, <bound method...01FA0857CE50>>, (<zmq.eventloo...001FA085A0100>, [<zmq.sugar.fr...001FA086C9A90>, <zmq.sugar.fr...001FA0869CA90>, <zmq.sugar.fr...001FA0869C880>, <zmq.sugar.fr...001FA086E9040>, <zmq.sugar.fr...001FA086E90F0>, <zmq.sugar.fr...001FA086E91A0>, ...]))>,),
#  <Handle IOLoop.add_future.<locals>.<lambda>(<Future finis...91A0>, ...]))>) at c:\users\subhadeep banerjee\appdata\local\programs\python\python38\lib\site-packages\tornado\ioloop.py:688>,
#  <function ipykernel.kernelbase.Kernel.schedule_dispatch.<locals>.<lambda>()>,
#  <bound method IOLoop._run_callback of <tornado.platform.asyncio.AsyncIOMainLoop object at 0x000001FA086012B0>>,
#  functools.partial(<function Kernel.schedule_dispatch.<locals>.<lambda> at 0x000001FA086CE9D0>),
#  (functools.partial(<function Kernel.schedule_dispatch.<locals>.<lambda> at 0x000001FA086CE9D0>),),
#  <Handle IOLoop._run_callback(functools.par...01FA086CE9D0>))>,
#  <Context at 0x1fa08638bc0>,
#  [<socket.socket fd=1152, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=0, laddr=('127.0.0.1', 53187), raddr=('127.0.0.1', 53188)>,
#   932,
#   400],
#  [],
#  ([<socket.socket fd=1152, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=0, laddr=('127.0.0.1', 53187), raddr=('127.0.0.1', 53188)>,
#    932,
#    400],
#   []),
#  <function asyncio.windows_events.IocpProactor.recv.<locals>.finish_recv(trans, key, ov)>,
#  <_OverlappedFuture pending overlapped=<pending, 0x1fa086ce940> cb=[BaseProactorEventLoop._loop_self_reading()]>,
#  (<_OverlappedFuture pending overlapped=<pending, 0x1fa086ce940> cb=[BaseProactorEventLoop._loop_self_reading()]>,
#   <_overlapped.Overlapped at 0x1fa086ce930>,
#   <socket.socket fd=1128, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=0, laddr=('127.0.0.1', 53185), raddr=('127.0.0.1', 53186)>,
#   <function asyncio.windows_events.IocpProactor.recv.<locals>.finish_recv(trans, key, ov)>),
#  <bound method BaseProactorEventLoop._loop_self_reading of <ProactorEventLoop running=True closed=False debug=False>>,
#  <Context at 0x1fa08654800>,
#  [],
#  <function Context.run>,
#  (<function tornado.ioloop.IOLoop.add_future.<locals>.<lambda>(f)>,
#   <Future finished result=(10, 5, <bound method...01FA0857CE50>>, (<zmq.eventloo...001FA085A0100>, [<zmq.sugar.fr...001FA086C9A90>, <zmq.sugar.fr...001FA0869CA90>, <zmq.sugar.fr...001FA0869C880>, <zmq.sugar.fr...001FA086E9040>, <zmq.sugar.fr...001FA086E90F0>, <zmq.sugar.fr...001FA086E91A0>, ...]))>),
#  functools.partial(<function Runner.handle_yield.<locals>.inner at 0x000001FA086CE8B0>, <Future finished result=(10, 5, <bound method...01FA0857CE50>>, (<zmq.eventloo...001FA085A0100>, [<zmq.sugar.fr...001FA086C9A90>, <zmq.sugar.fr...001FA0869CA90>, <zmq.sugar.fr...001FA0869C880>, <zmq.sugar.fr...001FA086E9040>, <zmq.sugar.fr...001FA086E90F0>, <zmq.sugar.fr...001FA086E91A0>, ...]))>),
#  (<Future finished result=(10, 5, <bound method...01FA0857CE50>>, (<zmq.eventloo...001FA085A0100>, [<zmq.sugar.fr...001FA086C9A90>, <zmq.sugar.fr...001FA0869CA90>, <zmq.sugar.fr...001FA0869C880>, <zmq.sugar.fr...001FA086E9040>, <zmq.sugar.fr...001FA086E90F0>, <zmq.sugar.fr...001FA086E91A0>, ...]))>,),
#  <bound method Runner.run of <tornado.gen.Runner object at 0x000001FA086D15B0>>,
#  (<ipykernel.ipkernel.IPythonKernel at 0x1fa0857ce50>,
#   <zmq.eventloop.zmqstream.ZMQStream at 0x1fa085a0100>,
#   [<zmq.sugar.frame.Frame at 0x1fa086c9a90>,
#    <zmq.sugar.frame.Frame at 0x1fa0869ca90>,
#    <zmq.sugar.frame.Frame at 0x1fa0869c880>,
#    <zmq.sugar.frame.Frame at 0x1fa086e9040>,
#    <zmq.sugar.frame.Frame at 0x1fa086e90f0>,
#    <zmq.sugar.frame.Frame at 0x1fa086e91a0>,
#    <zmq.sugar.frame.Frame at 0x1fa086e9250>]),
#  <cell at 0x000001FA086D1220: empty>,
#  <Future pending>,
#  <Context at 0x1fa08678dc0>,
#  <function Context.run>,
#  <generator object Kernel.dispatch_shell at 0x000001FA085E7EB0>,
#  <frame at 0x000001FA07FBF7A0, file 'c:\\users\\subhadeep banerjee\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\ipykernel\\kernelbase.py', line 265, code dispatch_shell>,
#  [b'45c6e213fb1b4b528fc52742791acad0'],
#  {'header': {'msg_id': '5a1ab03dc4f54839abaf14821c3e48a7',
#    'username': 'username',
#    'session': '45c6e213fb1b4b528fc52742791acad0',
#    'msg_type': 'execute_request',
#    'version': '5.2',
#    'date': datetime.datetime(2021, 1, 20, 21, 35, 34, 238360, tzinfo=datetime.timezone.utc)},
#   'msg_id': '5a1ab03dc4f54839abaf14821c3e48a7',
#   'msg_type': 'execute_request',
#   'parent_header': {},
#   'metadata': {},
#   'content': {'code': '# Returns a list of all objects tracked by the collector, excluding the list returned. \n# If generation is not None, return only the objects tracked by the collector that are in that generation.\ngc.get_objects(generation=None)',
#    'silent': False,
#    'store_history': True,
#    'user_expressions': {},
#    'allow_stdin': True,
#    'stop_on_error': True},
#   'buffers': []},
#  {'code': '# Returns a list of all objects tracked by the collector, excluding the list returned. \n# If generation is not None, return only the objects tracked by the collector that are in that generation.\ngc.get_objects(generation=None)',
#   'silent': False,
#   'store_history': True,
#   'user_expressions': {},
#   'allow_stdin': True,
#   'stop_on_error': True},
#  [],
#  [b'kernel.0b091999-8b54-4c74-8a2b-412ad341b312.status',
#   b'<IDS|MSG>',
#   b'b105e5ff396797b3ddd332ddc046fadad4dec1a86e75b98d74d3bb466f94dc1f',
#   b'{"msg_id":"4f0d31c9-57faaa7b68eec10de22bcc16_19","msg_type":"status","username":"username","session":"4f0d31c9-57faaa7b68eec10de22bcc16","date":"2021-01-20T21:35:34.238360Z","version":"5.3"}',
#   b'{"msg_id":"5a1ab03dc4f54839abaf14821c3e48a7","username":"username","session":"45c6e213fb1b4b528fc52742791acad0","msg_type":"execute_request","version":"5.2","date":"2021-01-20T21:35:34.238360Z"}',
#   b'{}',
#   b'{"execution_state":"busy"}'],
#  ([b'kernel.0b091999-8b54-4c74-8a2b-412ad341b312.status',
#    b'<IDS|MSG>',
#    b'b105e5ff396797b3ddd332ddc046fadad4dec1a86e75b98d74d3bb466f94dc1f',
#    b'{"msg_id":"4f0d31c9-57faaa7b68eec10de22bcc16_19","msg_type":"status","username":"username","session":"4f0d31c9-57faaa7b68eec10de22bcc16","date":"2021-01-20T21:35:34.238360Z","version":"5.3"}',
#    b'{"msg_id":"5a1ab03dc4f54839abaf14821c3e48a7","username":"username","session":"45c6e213fb1b4b528fc52742791acad0","msg_type":"execute_request","version":"5.2","date":"2021-01-20T21:35:34.238360Z"}',
#    b'{}',
#    b'{"execution_state":"busy"}'],),
#  <cell at 0x000001FA0868C070: tuple object at 0x000001FA086483A0>,
#  <cell at 0x000001FA0868C1C0: dict object at 0x000001FA086EA4C0>,
#  <cell at 0x000001FA0868C2B0: IOPubThread object at 0x000001FA085A6850>,
#  (<cell at 0x000001FA0868C070: tuple object at 0x000001FA086483A0>,
#   <cell at 0x000001FA0868C1C0: dict object at 0x000001FA086EA4C0>,
#   <cell at 0x000001FA0868C2B0: IOPubThread object at 0x000001FA085A6850>),
#  <function ipykernel.iostream.IOPubThread.send_multipart.<locals>.<lambda>()>,
#  (<ipykernel.ipkernel.IPythonKernel at 0x1fa0857ce50>,
#   <zmq.eventloop.zmqstream.ZMQStream at 0x1fa085a0100>,
#   [b'45c6e213fb1b4b528fc52742791acad0'],
#   {'header': {'msg_id': '5a1ab03dc4f54839abaf14821c3e48a7',
#     'username': 'username',
#     'session': '45c6e213fb1b4b528fc52742791acad0',
#     'msg_type': 'execute_request',
#     'version': '5.2',
#     'date': datetime.datetime(2021, 1, 20, 21, 35, 34, 238360, tzinfo=datetime.timezone.utc)},
#    'msg_id': '5a1ab03dc4f54839abaf14821c3e48a7',
#    'msg_type': 'execute_request',
#    'parent_header': {},
#    'metadata': {},
#    'content': {'code': '# Returns a list of all objects tracked by the collector, excluding the list returned. \n# If generation is not None, return only the objects tracked by the collector that are in that generation.\ngc.get_objects(generation=None)',
#     'silent': False,
#     'store_history': True,
#     'user_expressions': {},
#     'allow_stdin': True,
#     'stop_on_error': True},
#    'buffers': []}),
#  <cell at 0x000001FA0868C130: empty>,
#  <Future pending>,
#  <Context at 0x1fa08678ec0>,
#  <function Context.run>,
#  <generator object Kernel.execute_request at 0x000001FA086A3120>,
#  <frame at 0x000001FA07FFC7B0, file 'c:\\users\\subhadeep banerjee\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\ipykernel\\kernelbase.py', line 540, code execute_request>,
#  [b'kernel.0b091999-8b54-4c74-8a2b-412ad341b312.execute_input',
#   b'<IDS|MSG>',
#   b'602218fcae30ed168fc911ccbec6d9bf9fc506a483a826523d1ed623c26af2d7',
#   b'{"msg_id":"4f0d31c9-57faaa7b68eec10de22bcc16_20","msg_type":"execute_input","username":"username","session":"4f0d31c9-57faaa7b68eec10de22bcc16","date":"2021-01-20T21:35:34.238360Z","version":"5.3"}',
#   b'{"msg_id":"5a1ab03dc4f54839abaf14821c3e48a7","username":"username","session":"45c6e213fb1b4b528fc52742791acad0","msg_type":"execute_request","version":"5.2","date":"2021-01-20T21:35:34.238360Z"}',
#   b'{}',
#   b'{"code":"# Returns a list of all objects tracked by the collector, excluding the list returned. \\n# If generation is not None, return only the objects tracked by the collector that are in that generation.\\ngc.get_objects(generation=None)","execution_count":3}'],
#  ([b'kernel.0b091999-8b54-4c74-8a2b-412ad341b312.execute_input',
#    b'<IDS|MSG>',
#    b'602218fcae30ed168fc911ccbec6d9bf9fc506a483a826523d1ed623c26af2d7',
#    b'{"msg_id":"4f0d31c9-57faaa7b68eec10de22bcc16_20","msg_type":"execute_input","username":"username","session":"4f0d31c9-57faaa7b68eec10de22bcc16","date":"2021-01-20T21:35:34.238360Z","version":"5.3"}',
#    b'{"msg_id":"5a1ab03dc4f54839abaf14821c3e48a7","username":"username","session":"45c6e213fb1b4b528fc52742791acad0","msg_type":"execute_request","version":"5.2","date":"2021-01-20T21:35:34.238360Z"}',
#    b'{}',
#    b'{"code":"# Returns a list of all objects tracked by the collector, excluding the list returned. \\n# If generation is not None, return only the objects tracked by the collector that are in that generation.\\ngc.get_objects(generation=None)","execution_count":3}'],),
#  <cell at 0x000001FA0868CA30: tuple object at 0x000001FA086236A0>,
#  <cell at 0x000001FA0868C610: dict object at 0x000001FA086CCF00>,
#  <cell at 0x000001FA0868CB80: IOPubThread object at 0x000001FA085A6850>,
#  (<cell at 0x000001FA0868CA30: tuple object at 0x000001FA086236A0>,
#   <cell at 0x000001FA0868C610: dict object at 0x000001FA086CCF00>,
#   <cell at 0x000001FA0868CB80: IOPubThread object at 0x000001FA085A6850>),
#  <function ipykernel.iostream.IOPubThread.send_multipart.<locals>.<lambda>()>,
#  (<ipykernel.ipkernel.IPythonKernel at 0x1fa0857ce50>,
#   '# Returns a list of all objects tracked by the collector, excluding the list returned. \n# If generation is not None, return only the objects tracked by the collector that are in that generation.\ngc.get_objects(generation=None)',
#   False,
#   True,
#   {},
#   True),
#  <cell at 0x000001FA0868C490: empty>,
#  <Future pending>,
#  <Context at 0x1fa08678200>,
#  <function Context.run>,
#  <cell at 0x000001FA0868CB20: ZMQInteractiveShell object at 0x000001FA0857CB80>,
#  <generator object IPythonKernel.do_execute at 0x000001FA086A3200>,
#  <frame at 0x000001FA07D8B620, file 'c:\\users\\subhadeep banerjee\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\ipykernel\\ipkernel.py', line 302, code do_execute>,
#  <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x000001FA0857CE50>>,
#  <bound method Kernel.getpass of <ipykernel.ipkernel.IPythonKernel object at 0x000001FA0857CE50>>,
#  <bound method InteractiveShell.run_cell_async of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001FA0857CB80>>,
#  <bound method InteractiveShell.should_run_async of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001FA0857CB80>>,
#  <bound method ZMQInteractiveShell.run_cell of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001FA0857CB80>>,
#  ('# Returns a list of all objects tracked by the collector, excluding the list returned. \n# If generation is not None, return only the objects tracked by the collector that are in that generation.\ngc.get_objects(generation=None)',),
#  <bound method InteractiveShell.run_cell of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001FA0857CB80>>,
#  ('store_history', 'silent'),
#  <cell at 0x000001FA0868CB50: ExecutionResult object at 0x000001FA0868CBB0>,
#  <cell at 0x000001FA0868CAC0: ZMQInteractiveShell object at 0x000001FA0857CB80>,
#  <cell at 0x000001FA0868C880: bool object at 0x00007FFB6DE9C750>,
#  <coroutine object InteractiveShell.run_cell_async at 0x000001FA08657C40>,
#  <frame at 0x000001FA06A7A740, file 'c:\\users\\subhadeep banerjee\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\IPython\\core\\interactiveshell.py', line 3146, code run_cell_async>,
#  <ExecutionInfo object at 1fa0868cf40, raw_cell="# Returns a list of all objects tracked by the col.." store_history=True silent=False shell_futures=True>,
#  <ExecutionResult object at 1fa0868cbb0, execution_count=3 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 1fa0868cf40, raw_cell="# Returns a list of all objects tracked by the col.." store_history=True silent=False shell_futures=True> result=None>,
#  {'info': <ExecutionInfo object at 1fa0868cf40, raw_cell="# Returns a list of all objects tracked by the col.." store_history=True silent=False shell_futures=True>,
#   'execution_count': 3},
#  (<cell at 0x000001FA0868CB50: ExecutionResult object at 0x000001FA0868CBB0>,
#   <cell at 0x000001FA0868CAC0: ZMQInteractiveShell object at 0x000001FA0857CB80>,
#   <cell at 0x000001FA0868C880: bool object at 0x00007FFB6DE9C750>),
#  <function IPython.core.interactiveshell.InteractiveShell.run_cell_async.<locals>.error_before_exec(value)>,
#  (3,
#   '# Returns a list of all objects tracked by the collector, excluding the list returned. \n# If generation is not None, return only the objects tracked by the collector that are in that generation.\ngc.get_objects(generation=None)',
#   '# Returns a list of all objects tracked by the collector, excluding the list returned. \n# If generation is not None, return only the objects tracked by the collector that are in that generation.\ngc.get_objects(generation=None)'),
#  <bound method BuiltinTrap.__exit__ of <IPython.core.builtin_trap.BuiltinTrap object at 0x000001FA0861A280>>,
#  ['# Returns a list of all objects tracked by the collector, excluding the list returned. \n',
#   '# If generation is not None, return only the objects tracked by the collector that are in that generation.\n',
#   'gc.get_objects(generation=None)\n'],
#  (227,
#   1611178534.239353,
#   ['# Returns a list of all objects tracked by the collector, excluding the list returned. \n',
#    '# If generation is not None, return only the objects tracked by the collector that are in that generation.\n',
#    'gc.get_objects(generation=None)\n'],
#   '<ipython-input-3-5638f3a9307c>'),
#  <bound method DisplayTrap.__exit__ of <IPython.core.display_trap.DisplayTrap object at 0x000001FA08623550>>,
#  <_ast.Module at 0x1fa0868c940>,
#  [<_ast.Expr at 0x1fa0868c7f0>],
#  <_ast.Expr at 0x1fa0868c7f0>,
#  <_ast.Call at 0x1fa0868cfa0>,
#  <_ast.Attribute at 0x1fa0868c8e0>,
#  <_ast.Name at 0x1fa0868ca00>,
#  {'id': 'gc',
#   'ctx': <_ast.Load at 0x1fa04ca5eb0>,
#   'lineno': 3,
#   'col_offset': 0,
#   'end_lineno': 3,
#   'end_col_offset': 2},
#  {'value': <_ast.Name at 0x1fa0868ca00>,
#   'attr': 'get_objects',
#   'ctx': <_ast.Load at 0x1fa04ca5eb0>,
#   'lineno': 3,
#   'col_offset': 0,
#   'end_lineno': 3,
#   'end_col_offset': 14},
#  {'func': <_ast.Attribute at 0x1fa0868c8e0>,
#   'args': [],
#   'keywords': [<_ast.keyword at 0x1fa0868c5e0>],
#   'lineno': 3,
#   'col_offset': 0,
#   'end_lineno': 3,
#   'end_col_offset': 31},
#  [],
#  [<_ast.keyword at 0x1fa0868c5e0>],
#  <_ast.keyword at 0x1fa0868c5e0>,
#  <_ast.Constant at 0x1fa0868cc40>,
#  {'arg': 'generation', 'value': <_ast.Constant at 0x1fa0868cc40>},
#  {'value': <_ast.Call at 0x1fa0868cfa0>,
#   'lineno': 3,
#   'col_offset': 0,
#   'end_lineno': 3,
#   'end_col_offset': 31},
#  {'body': [<_ast.Expr at 0x1fa0868c7f0>], 'type_ignores': []},
#  [],
#  <cell at 0x000001FA0868CD90: bool object at 0x00007FFB6DE9C770>,
#  <coroutine object InteractiveShell.run_ast_nodes at 0x000001FA08657CC0>,
#  <frame at 0x000001FA06B6BD90, file 'c:\\users\\subhadeep banerjee\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\IPython\\core\\interactiveshell.py', line 3338, code run_ast_nodes>,
#  [],
#  [<_ast.Expr at 0x1fa0868c7f0>],
#  <function IPython.core.interactiveshell.InteractiveShell.run_ast_nodes.<locals>.compare(code)>,
#  [(<_ast.Expr at 0x1fa0868c7f0>, 'single')],
#  (<_ast.Expr at 0x1fa0868c7f0>, 'single'),
#  <list_iterator at 0x1fa0868cdf0>,
#  [<_ast.Expr at 0x1fa0868c7f0>],
#  <_ast.Interactive at 0x1fa0868cc70>,
#  {'body': [<_ast.Expr at 0x1fa0868c7f0>]},
#  ('generation',),
#  ('gc', 'get_objects'),
#  (None, ('generation',)),
#  <coroutine object InteractiveShell.run_code at 0x000001FA08657D40>,
#  <frame at 0x000001FA07FFA3B0, file 'c:\\users\\subhadeep banerjee\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\IPython\\core\\interactiveshell.py', line 3418, code run_code>,
#  <bound method InteractiveShell.excepthook of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001FA0857CB80>>,
#  _FlagAction(option_strings=['--debug'], dest='debug', nargs=0, const=traitlets.Undefined, default='==SUPPRESS==', type=None, choices=None, help=None, metavar=None),
#  {'flag': {'IPKernelApp': {'log_level': 10}},
#   'alias': None,
#   'option_strings': ['--debug'],
#   'dest': 'debug',
#   'nargs': 0,
#   'const': traitlets.Undefined,
#   'default': '==SUPPRESS==',
#   'type': None,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': None,
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _FlagAction(option_strings=['--quiet'], dest='quiet', nargs=0, const=traitlets.Undefined, default='==SUPPRESS==', type=None, choices=None, help=None, metavar=None),
#  {'flag': {'IPKernelApp': {'log_level': 50}},
#   'alias': None,
#   'option_strings': ['--quiet'],
#   'dest': 'quiet',
#   'nargs': 0,
#   'const': traitlets.Undefined,
#   'default': '==SUPPRESS==',
#   'type': None,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': None,
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _FlagAction(option_strings=['--init'], dest='init', nargs=0, const=traitlets.Undefined, default='==SUPPRESS==', type=None, choices=None, help=None, metavar=None),
#  {'flag': {'IPKernelApp': {'copy_config_files': True, 'auto_create': True}},
#   'alias': None,
#   'option_strings': ['--init'],
#   'dest': 'init',
#   'nargs': 0,
#   'const': traitlets.Undefined,
#   'default': '==SUPPRESS==',
#   'type': None,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': None,
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _FlagAction(option_strings=['--no-stdout'], dest='no_stdout', nargs=0, const=traitlets.Undefined, default='==SUPPRESS==', type=None, choices=None, help=None, metavar=None),
#  {'flag': {'IPKernelApp': {'no_stdout': True}},
#   'alias': None,
#   'option_strings': ['--no-stdout'],
#   'dest': 'no_stdout',
#   'nargs': 0,
#   'const': traitlets.Undefined,
#   'default': '==SUPPRESS==',
#   'type': None,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': None,
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _FlagAction(option_strings=['--no-stderr'], dest='no_stderr', nargs=0, const=traitlets.Undefined, default='==SUPPRESS==', type=None, choices=None, help=None, metavar=None),
#  {'flag': {'IPKernelApp': {'no_stderr': True}},
#   'alias': None,
#   'option_strings': ['--no-stderr'],
#   'dest': 'no_stderr',
#   'nargs': 0,
#   'const': traitlets.Undefined,
#   'default': '==SUPPRESS==',
#   'type': None,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': None,
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _FlagAction(option_strings=['--trio-loop'], dest='trio_loop', nargs=0, const=traitlets.Undefined, default='==SUPPRESS==', type=None, choices=None, help=None, metavar=None),
#  {'flag': {'ZMQInteractiveShell': {'trio_loop': False}},
#   'alias': None,
#   'option_strings': ['--trio-loop'],
#   'dest': 'trio_loop',
#   'nargs': 0,
#   'const': traitlets.Undefined,
#   'default': '==SUPPRESS==',
#   'type': None,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': None,
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _FlagAction(option_strings=['--autoindent'], dest='autoindent', nargs=0, const=traitlets.Undefined, default='==SUPPRESS==', type=None, choices=None, help=None, metavar=None),
#  {'flag': {'ZMQInteractiveShell': {'autoindent': True}},
#   'alias': None,
#   'option_strings': ['--autoindent'],
#   'dest': 'autoindent',
#   'nargs': 0,
#   'const': traitlets.Undefined,
#   'default': '==SUPPRESS==',
#   'type': None,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': None,
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _FlagAction(option_strings=['--no-autoindent'], dest='no_autoindent', nargs=0, const=traitlets.Undefined, default='==SUPPRESS==', type=None, choices=None, help=None, metavar=None),
#  {'flag': {'ZMQInteractiveShell': {'autoindent': False}},
#   'alias': None,
#   'option_strings': ['--no-autoindent'],
#   'dest': 'no_autoindent',
#   'nargs': 0,
#   'const': traitlets.Undefined,
#   'default': '==SUPPRESS==',
#   'type': None,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': None,
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _FlagAction(option_strings=['--automagic'], dest='automagic', nargs=0, const=traitlets.Undefined, default='==SUPPRESS==', type=None, choices=None, help=None, metavar=None),
#  {'flag': {'ZMQInteractiveShell': {'automagic': True}},
#   'alias': None,
#   'option_strings': ['--automagic'],
#   'dest': 'automagic',
#   'nargs': 0,
#   'const': traitlets.Undefined,
#   'default': '==SUPPRESS==',
#   'type': None,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': None,
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _FlagAction(option_strings=['--no-automagic'], dest='no_automagic', nargs=0, const=traitlets.Undefined, default='==SUPPRESS==', type=None, choices=None, help=None, metavar=None),
#  {'flag': {'ZMQInteractiveShell': {'automagic': False}},
#   'alias': None,
#   'option_strings': ['--no-automagic'],
#   'dest': 'no_automagic',
#   'nargs': 0,
#   'const': traitlets.Undefined,
#   'default': '==SUPPRESS==',
#   'type': None,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': None,
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _FlagAction(option_strings=['--pdb'], dest='pdb', nargs=0, const=traitlets.Undefined, default='==SUPPRESS==', type=None, choices=None, help=None, metavar=None),
#  {'flag': {'ZMQInteractiveShell': {'pdb': True}},
#   'alias': None,
#   'option_strings': ['--pdb'],
#   'dest': 'pdb',
#   'nargs': 0,
#   'const': traitlets.Undefined,
#   'default': '==SUPPRESS==',
#   'type': None,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': None,
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _FlagAction(option_strings=['--no-pdb'], dest='no_pdb', nargs=0, const=traitlets.Undefined, default='==SUPPRESS==', type=None, choices=None, help=None, metavar=None),
#  {'flag': {'ZMQInteractiveShell': {'pdb': False}},
#   'alias': None,
#   'option_strings': ['--no-pdb'],
#   'dest': 'no_pdb',
#   'nargs': 0,
#   'const': traitlets.Undefined,
#   'default': '==SUPPRESS==',
#   'type': None,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': None,
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _FlagAction(option_strings=['--pprint'], dest='pprint', nargs=0, const=traitlets.Undefined, default='==SUPPRESS==', type=None, choices=None, help=None, metavar=None),
#  {'flag': {'PlainTextFormatter': {'pprint': True}},
#   'alias': None,
#   'option_strings': ['--pprint'],
#   'dest': 'pprint',
#   'nargs': 0,
#   'const': traitlets.Undefined,
#   'default': '==SUPPRESS==',
#   'type': None,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': None,
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _FlagAction(option_strings=['--no-pprint'], dest='no_pprint', nargs=0, const=traitlets.Undefined, default='==SUPPRESS==', type=None, choices=None, help=None, metavar=None),
#  {'flag': {'PlainTextFormatter': {'pprint': False}},
#   'alias': None,
#   'option_strings': ['--no-pprint'],
#   'dest': 'no_pprint',
#   'nargs': 0,
#   'const': traitlets.Undefined,
#   'default': '==SUPPRESS==',
#   'type': None,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': None,
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _FlagAction(option_strings=['--color-info'], dest='color_info', nargs=0, const=traitlets.Undefined, default='==SUPPRESS==', type=None, choices=None, help=None, metavar=None),
#  {'flag': {'ZMQInteractiveShell': {'color_info': True}},
#   'alias': None,
#   'option_strings': ['--color-info'],
#   'dest': 'color_info',
#   'nargs': 0,
#   'const': traitlets.Undefined,
#   'default': '==SUPPRESS==',
#   'type': None,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': None,
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _FlagAction(option_strings=['--no-color-info'], dest='no_color_info', nargs=0, const=traitlets.Undefined, default='==SUPPRESS==', type=None, choices=None, help=None, metavar=None),
#  {'flag': {'ZMQInteractiveShell': {'color_info': False}},
#   'alias': None,
#   'option_strings': ['--no-color-info'],
#   'dest': 'no_color_info',
#   'nargs': 0,
#   'const': traitlets.Undefined,
#   'default': '==SUPPRESS==',
#   'type': None,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': None,
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _FlagAction(option_strings=['--ignore-cwd'], dest='ignore_cwd', nargs=0, const=traitlets.Undefined, default='==SUPPRESS==', type=None, choices=None, help=None, metavar=None),
#  {'flag': {'IPKernelApp': {'ignore_cwd': True}},
#   'alias': None,
#   'option_strings': ['--ignore-cwd'],
#   'dest': 'ignore_cwd',
#   'nargs': 0,
#   'const': traitlets.Undefined,
#   'default': '==SUPPRESS==',
#   'type': None,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': None,
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _FlagAction(option_strings=['--no-ignore-cwd'], dest='no_ignore_cwd', nargs=0, const=traitlets.Undefined, default='==SUPPRESS==', type=None, choices=None, help=None, metavar=None),
#  {'flag': {'IPKernelApp': {'ignore_cwd': False}},
#   'alias': None,
#   'option_strings': ['--no-ignore-cwd'],
#   'dest': 'no_ignore_cwd',
#   'nargs': 0,
#   'const': traitlets.Undefined,
#   'default': '==SUPPRESS==',
#   'type': None,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': None,
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _FlagAction(option_strings=['--nosep'], dest='nosep', nargs=0, const=traitlets.Undefined, default='==SUPPRESS==', type=None, choices=None, help=None, metavar=None),
#  {'flag': {'ZMQInteractiveShell': {'separate_in': '',
#     'separate_out': '',
#     'separate_out2': ''}},
#   'alias': None,
#   'option_strings': ['--nosep'],
#   'dest': 'nosep',
#   'nargs': 0,
#   'const': traitlets.Undefined,
#   'default': '==SUPPRESS==',
#   'type': None,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': None,
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _FlagAction(option_strings=['--secure'], dest='secure', nargs=0, const=traitlets.Undefined, default='==SUPPRESS==', type=None, choices=None, help=None, metavar=None),
#  {'flag': {'Session': {'key': b'1b6c3c0f-eea42a6e67b329cf35c3a885',
#     'keyfile': ''}},
#   'alias': None,
#   'option_strings': ['--secure'],
#   'dest': 'secure',
#   'nargs': 0,
#   'const': traitlets.Undefined,
#   'default': '==SUPPRESS==',
#   'type': None,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': None,
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _FlagAction(option_strings=['--no-secure'], dest='no_secure', nargs=0, const=traitlets.Undefined, default='==SUPPRESS==', type=None, choices=None, help=None, metavar=None),
#  {'flag': {'Session': {'key': b'', 'keyfile': ''}},
#   'alias': None,
#   'option_strings': ['--no-secure'],
#   'dest': 'no_secure',
#   'nargs': 0,
#   'const': traitlets.Undefined,
#   'default': '==SUPPRESS==',
#   'type': None,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': None,
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _StoreAction(option_strings=['--profile-dir'], dest='ProfileDir__DOT__location', nargs=None, const=None, default='==SUPPRESS==', type=<class 'str'>, choices=None, help=None, metavar='ProfileDir.location'),
#  {'option_strings': ['--profile-dir'],
#   'dest': 'ProfileDir__DOT__location',
#   'nargs': None,
#   'const': None,
#   'default': '==SUPPRESS==',
#   'type': str,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': 'ProfileDir.location',
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _StoreAction(option_strings=['--profile'], dest='IPKernelApp__DOT__profile', nargs=None, const=None, default='==SUPPRESS==', type=<class 'str'>, choices=None, help=None, metavar='IPKernelApp.profile'),
#  {'option_strings': ['--profile'],
#   'dest': 'IPKernelApp__DOT__profile',
#   'nargs': None,
#   'const': None,
#   'default': '==SUPPRESS==',
#   'type': str,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': 'IPKernelApp.profile',
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _StoreAction(option_strings=['--ipython-dir'], dest='IPKernelApp__DOT__ipython_dir', nargs=None, const=None, default='==SUPPRESS==', type=<class 'str'>, choices=None, help=None, metavar='IPKernelApp.ipython_dir'),
#  {'option_strings': ['--ipython-dir'],
#   'dest': 'IPKernelApp__DOT__ipython_dir',
#   'nargs': None,
#   'const': None,
#   'default': '==SUPPRESS==',
#   'type': str,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': 'IPKernelApp.ipython_dir',
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _StoreAction(option_strings=['--log-level'], dest='IPKernelApp__DOT__log_level', nargs=None, const=None, default='==SUPPRESS==', type=<class 'str'>, choices=None, help=None, metavar='IPKernelApp.log_level'),
#  {'option_strings': ['--log-level'],
#   'dest': 'IPKernelApp__DOT__log_level',
#   'nargs': None,
#   'const': None,
#   'default': '==SUPPRESS==',
#   'type': str,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': 'IPKernelApp.log_level',
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _StoreAction(option_strings=['--config'], dest='IPKernelApp__DOT__extra_config_file', nargs=None, const=None, default='==SUPPRESS==', type=<class 'str'>, choices=None, help=None, metavar='IPKernelApp.extra_config_file'),
#  {'option_strings': ['--config'],
#   'dest': 'IPKernelApp__DOT__extra_config_file',
#   'nargs': None,
#   'const': None,
#   'default': '==SUPPRESS==',
#   'type': str,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': 'IPKernelApp.extra_config_file',
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _StoreAction(option_strings=['--ip'], dest='IPKernelApp__DOT__ip', nargs=None, const=None, default='==SUPPRESS==', type=<class 'str'>, choices=None, help=None, metavar='IPKernelApp.ip'),
#  {'option_strings': ['--ip'],
#   'dest': 'IPKernelApp__DOT__ip',
#   'nargs': None,
#   'const': None,
#   'default': '==SUPPRESS==',
#   'type': str,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': 'IPKernelApp.ip',
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _StoreAction(option_strings=['--hb'], dest='IPKernelApp__DOT__hb_port', nargs=None, const=None, default='==SUPPRESS==', type=<class 'str'>, choices=None, help=None, metavar='IPKernelApp.hb_port'),
#  {'option_strings': ['--hb'],
#   'dest': 'IPKernelApp__DOT__hb_port',
#   'nargs': None,
#   'const': None,
#   'default': '==SUPPRESS==',
#   'type': str,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': 'IPKernelApp.hb_port',
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _StoreAction(option_strings=['--shell'], dest='IPKernelApp__DOT__shell_port', nargs=None, const=None, default='==SUPPRESS==', type=<class 'str'>, choices=None, help=None, metavar='IPKernelApp.shell_port'),
#  {'option_strings': ['--shell'],
#   'dest': 'IPKernelApp__DOT__shell_port',
#   'nargs': None,
#   'const': None,
#   'default': '==SUPPRESS==',
#   'type': str,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': 'IPKernelApp.shell_port',
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _StoreAction(option_strings=['--iopub'], dest='IPKernelApp__DOT__iopub_port', nargs=None, const=None, default='==SUPPRESS==', type=<class 'str'>, choices=None, help=None, metavar='IPKernelApp.iopub_port'),
#  {'option_strings': ['--iopub'],
#   'dest': 'IPKernelApp__DOT__iopub_port',
#   'nargs': None,
#   'const': None,
#   'default': '==SUPPRESS==',
#   'type': str,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': 'IPKernelApp.iopub_port',
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _StoreAction(option_strings=['--stdin'], dest='IPKernelApp__DOT__stdin_port', nargs=None, const=None, default='==SUPPRESS==', type=<class 'str'>, choices=None, help=None, metavar='IPKernelApp.stdin_port'),
#  {'option_strings': ['--stdin'],
#   'dest': 'IPKernelApp__DOT__stdin_port',
#   'nargs': None,
#   'const': None,
#   'default': '==SUPPRESS==',
#   'type': str,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': 'IPKernelApp.stdin_port',
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _StoreAction(option_strings=['--control'], dest='IPKernelApp__DOT__control_port', nargs=None, const=None, default='==SUPPRESS==', type=<class 'str'>, choices=None, help=None, metavar='IPKernelApp.control_port'),
#  {'option_strings': ['--control'],
#   'dest': 'IPKernelApp__DOT__control_port',
#   'nargs': None,
#   'const': None,
#   'default': '==SUPPRESS==',
#   'type': str,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': 'IPKernelApp.control_port',
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _StoreAction(option_strings=['-f', '--f'], dest='IPKernelApp__DOT__connection_file', nargs=None, const=None, default='==SUPPRESS==', type=<class 'str'>, choices=None, help=None, metavar='IPKernelApp.connection_file'),
#  {'option_strings': ['-f', '--f'],
#   'dest': 'IPKernelApp__DOT__connection_file',
#   'nargs': None,
#   'const': None,
#   'default': '==SUPPRESS==',
#   'type': str,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': 'IPKernelApp.connection_file',
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _StoreAction(option_strings=['--transport'], dest='IPKernelApp__DOT__transport', nargs=None, const=None, default='==SUPPRESS==', type=<class 'str'>, choices=None, help=None, metavar='IPKernelApp.transport'),
#  {'option_strings': ['--transport'],
#   'dest': 'IPKernelApp__DOT__transport',
#   'nargs': None,
#   'const': None,
#   'default': '==SUPPRESS==',
#   'type': str,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': 'IPKernelApp.transport',
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _StoreAction(option_strings=['--autocall'], dest='ZMQInteractiveShell__DOT__autocall', nargs=None, const=None, default='==SUPPRESS==', type=<class 'str'>, choices=None, help=None, metavar='ZMQInteractiveShell.autocall'),
#  {'option_strings': ['--autocall'],
#   'dest': 'ZMQInteractiveShell__DOT__autocall',
#   'nargs': None,
#   'const': None,
#   'default': '==SUPPRESS==',
#   'type': str,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': 'ZMQInteractiveShell.autocall',
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _StoreAction(option_strings=['--colors'], dest='ZMQInteractiveShell__DOT__colors', nargs=None, const=None, default='==SUPPRESS==', type=<class 'str'>, choices=None, help=None, metavar='ZMQInteractiveShell.colors'),
#  {'option_strings': ['--colors'],
#   'dest': 'ZMQInteractiveShell__DOT__colors',
#   'nargs': None,
#   'const': None,
#   'default': '==SUPPRESS==',
#   'type': str,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': 'ZMQInteractiveShell.colors',
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
#  _StoreAction(option_strings=['--logfile'], dest='ZMQInteractiveShell__DOT__logfile', nargs=None, const=None, default='==SUPPRESS==', type=<class 'str'>, choices=None, help=None, metavar='ZMQInteractiveShell.logfile'),
#  {'option_strings': ['--logfile'],
#   'dest': 'ZMQInteractiveShell__DOT__logfile',
#   'nargs': None,
#   'const': None,
#   'default': '==SUPPRESS==',
#   'type': str,
#   'choices': None,
#   'required': False,
#   'help': None,
#   'metavar': 'ZMQInteractiveShell.logfile',
#   'container': <argparse._ArgumentGroup at 0x1fa0857c7f0>},
# ...
#  <method 'AddAccessDeniedAceEx' of 'PyACL' objects>,
#  <method 'AddMandatoryAce' of 'PyACL' objects>,
#  <method 'AddAccessDeniedObjectAce' of 'PyACL' objects>,
#  <method 'AddAuditAccessAce' of 'PyACL' objects>,
#  <method 'AddAuditAccessAceEx' of 'PyACL' objects>,
#  <method 'AddAuditAccessObjectAce' of 'PyACL' objects>,
#  <method 'GetAclSize' of 'PyACL' objects>,
#  <method 'GetAclRevision' of 'PyACL' objects>,
#  <method 'GetAceCount' of 'PyACL' objects>,
#  <method 'GetAce' of 'PyACL' objects>,
#  <method 'DeleteAce' of 'PyACL' objects>,
#  <method 'GetExplicitEntriesFromAcl' of 'PyACL' objects>,
#  <method 'SetEntriesInAcl' of 'PyACL' objects>,
#  <method 'GetEffectiveRightsFromAcl' of 'PyACL' objects>,
#  <method 'GetAuditedPermissionsFromAcl' of 'PyACL' objects>,
#  <weakref at 0x000001FA085CED10; to 'type' at 0x0000000070B902C0 (PyACL)>,
#  {'__getattribute__': <slot wrapper '__getattribute__' of 'pywintypes.datetime' objects>,
#   '__setattr__': <slot wrapper '__setattr__' of 'pywintypes.datetime' objects>,
#   '__delattr__': <slot wrapper '__delattr__' of 'pywintypes.datetime' objects>,
#   '__new__': <function datetime.__new__(*args, **kwargs)>,
#   'Format': <method 'Format' of 'pywintypes.datetime' objects>,
#   '__doc__': None},
#  <slot wrapper '__setattr__' of 'pywintypes.datetime' objects>,
#  <slot wrapper '__delattr__' of 'pywintypes.datetime' objects>,
#  <function datetime.__new__(*args, **kwargs)>,
#  <method 'Format' of 'pywintypes.datetime' objects>,
#  {1891182304: <weakref at 0x000001FA085CEEA0; to 'type' at 0x0000000070B926E0 (datetime)>},
#  <module 'win32api' from 'c:\\users\\subhadeep banerjee\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\win32\\win32api.pyd'>,
#  {'__name__': 'win32api',
#   '__doc__': 'Wraps general API functions that are not subsumed in the more specific modules',
#   '__package__': '',
#   '__loader__': <_frozen_importlib_external.ExtensionFileLoader at 0x1fa085a0220>,
#   '__spec__': ModuleSpec(name='win32api', loader=<_frozen_importlib_external.ExtensionFileLoader object at 0x000001FA085A0220>, origin='c:\\users\\subhadeep banerjee\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\win32\\win32api.pyd'),
#   'AbortSystemShutdown': <function win32api.AbortSystemShutdown>,
#   'InitiateSystemShutdown': <function win32api.InitiateSystemShutdown>,
#   'Apply': <function win32api.Apply>,
#   'Beep': <function win32api.Beep>,
#   'BeginUpdateResource': <function win32api.BeginUpdateResource>,
#   'ChangeDisplaySettings': <function win32api.ChangeDisplaySettings>,
#   'ChangeDisplaySettingsEx': <function win32api.ChangeDisplaySettingsEx>,
#   'ClipCursor': <function win32api.ClipCursor>,
#   'CloseHandle': <function win32api.CloseHandle>,
#   'CommandLineToArgv': <function win32api.CommandLineToArgv>,
#   'CopyFile': <function win32api.CopyFile>,
#   'DebugBreak': <function win32api.DebugBreak>,
#   'DeleteFile': <function win32api.DeleteFile>,
#   'DragQueryFile': <function win32api.DragQueryFile>,
#   'DragFinish': <function win32api.DragFinish>,
#   'DuplicateHandle': <function win32api.DuplicateHandle>,
#   'EndUpdateResource': <function win32api.EndUpdateResource>,
#   'EnumDisplayDevices': <function win32api.EnumDisplayDevices>,
#   'EnumDisplayMonitors': <function win32api.EnumDisplayMonitors>,
#   'EnumDisplaySettings': <function win32api.EnumDisplaySettings>,
#   'EnumDisplaySettingsEx': <function win32api.EnumDisplaySettingsEx>,
#   'EnumResourceLanguages': <function win32api.EnumResourceLanguages>,
#   'EnumResourceNames': <function win32api.EnumResourceNames>,
#   'EnumResourceTypes': <function win32api.EnumResourceTypes>,
#   'ExpandEnvironmentStrings': <function win32api.ExpandEnvironmentStrings>,
#   'ExitWindows': <function win32api.ExitWindows>,
#   'ExitWindowsEx': <function win32api.ExitWindowsEx>,
#   'FindFiles': <function win32api.FindFiles>,
#   'FindFirstChangeNotification': <function win32api.FindFirstChangeNotification>,
#   'FindNextChangeNotification': <function win32api.FindNextChangeNotification>,
#   'FindCloseChangeNotification': <function win32api.FindCloseChangeNotification>,
#   'FindExecutable': <function win32api.FindExecutable>,
#   'FormatMessage': <function win32api.FormatMessage>,
#   'FormatMessageW': <function win32api.FormatMessageW>,
#   'FreeLibrary': <function win32api.FreeLibrary>,
#   'GenerateConsoleCtrlEvent': <function win32api.GenerateConsoleCtrlEvent>,
#   'GetAsyncKeyState': <function win32api.GetAsyncKeyState>,
#   'GetCommandLine': <function win32api.GetCommandLine>,
#   'GetComputerName': <function win32api.GetComputerName>,
#   'GetComputerNameEx': <function win32api.GetComputerNameEx>,
#   'GetComputerObjectName': <function win32api.GetComputerObjectName>,
#   'GetMonitorInfo': <function win32api.GetMonitorInfo>,
#   'GetUserName': <function win32api.GetUserName>,
#   'GetUserNameEx': <function win32api.GetUserNameEx>,
#   'GetCursorPos': <function win32api.GetCursorPos>,
#   'GetCurrentThread': <function win32api.GetCurrentThread>,
#   'GetCurrentThreadId': <function win32api.GetCurrentThreadId>,
#   'GetCurrentProcessId': <function win32api.GetCurrentProcessId>,
#   'GetCurrentProcess': <function win32api.GetCurrentProcess>,
#   'GetConsoleTitle': <function win32api.GetConsoleTitle>,
#   'GetDateFormat': <function win32api.GetDateFormat>,
#   'GetDiskFreeSpace': <function win32api.GetDiskFreeSpace>,
#   'GetDiskFreeSpaceEx': <function win32api.GetDiskFreeSpaceEx>,
#   'GetDllDirectory': <function win32api.GetDllDirectory>,
#   'GetDomainName': <function win32api.GetDomainName>,
#   'GetEnvironmentVariable': <function win32api.GetEnvironmentVariable>,
#   'GetEnvironmentVariableW': <function win32api.GetEnvironmentVariableW>,
#   'GetFileAttributes': <function win32api.GetFileAttributes>,
#   'GetFileVersionInfo': <function win32api.GetFileVersionInfo>,
#   'GetFocus': <function win32api.GetFocus>,
#   'GetFullPathName': <function win32api.GetFullPathName>,
#   'GetHandleInformation': <function win32api.GetHandleInformation>,
#   'GetKeyboardLayout': <function win32api.GetKeyboardLayout>,
#   'GetKeyboardLayoutList': <function win32api.GetKeyboardLayoutList>,
#   'GetKeyboardLayoutName': <function win32api.GetKeyboardLayoutName>,
#   'GetKeyboardState': <function win32api.GetKeyboardState>,
#   'GetKeyState': <function win32api.GetKeyState>,
#   'GetLastError': <function win32api.GetLastError>,
#   'GetLastInputInfo': <function win32api.GetLastInputInfo>,
#   'GetLocalTime': <function win32api.GetLocalTime>,
#   'GetLongPathName': <function win32api.GetLongPathName>,
#   'GetLongPathNameW': <function win32api.GetLongPathNameW>,
#   'GetLogicalDrives': <function win32api.GetLogicalDrives>,
#   'GetLogicalDriveStrings': <function win32api.GetLogicalDriveStrings>,
#   'GetModuleFileName': <function win32api.GetModuleFileName>,
#   'GetModuleFileNameW': <function win32api.GetModuleFileNameW>,
#   'GetModuleHandle': <function win32api.GetModuleHandle>,
#   'GetPwrCapabilities': <function win32api.GetPwrCapabilities>,
#   'GetProfileSection': <function win32api.GetProfileSection>,
#   'GetProcAddress': <function win32api.GetProcAddress>,
#   'GetProfileVal': <function win32api.GetProfileVal>,
#   'GetShortPathName': <function win32api.GetShortPathName>,
#   'GetStdHandle': <function win32api.GetStdHandle>,
#   'GetSysColor': <function win32api.GetSysColor>,
#   'GetSystemDefaultLangID': <function win32api.GetSystemDefaultLangID>,
#   'GetSystemDefaultLCID': <function win32api.GetSystemDefaultLCID>,
#   'GetSystemDirectory': <function win32api.GetSystemDirectory>,
#   'GetSystemFileCacheSize': <function win32api.GetSystemFileCacheSize>,
#   'SetSystemFileCacheSize': <function win32api.SetSystemFileCacheSize>,
#   'GetSystemInfo': <function win32api.GetSystemInfo>,
#   'GetNativeSystemInfo': <function win32api.GetNativeSystemInfo>,
#   'GetSystemMetrics': <function win32api.GetSystemMetrics>,
#   'GetSystemTime': <function win32api.GetSystemTime>,
#   'GetTempFileName': <function win32api.GetTempFileName>,
#   'GetTempPath': <function win32api.GetTempPath>,
#   'GetThreadLocale': <function win32api.GetThreadLocale>,
#   'GetTickCount': <function win32api.GetTickCount>,
#   'GetTimeFormat': <function win32api.GetTimeFormat>,
#   'GetTimeZoneInformation': <function win32api.GetTimeZoneInformation>,
#   'GetVersion': <function win32api.GetVersion>,
#   'GetVersionEx': <function win32api.GetVersionEx>,
#   'GetVolumeInformation': <function win32api.GetVolumeInformation>,
#   'GetWindowsDirectory': <function win32api.GetWindowsDirectory>,
#   'GetWindowLong': <function win32api.GetWindowLong>,
#   'GetUserDefaultLangID': <function win32api.GetUserDefaultLangID>,
#   'GetUserDefaultLCID': <function win32api.GetUserDefaultLCID>,
#   'GlobalMemoryStatus': <function win32api.GlobalMemoryStatus>,
#   'GlobalMemoryStatusEx': <function win32api.GlobalMemoryStatusEx>,
#   'keybd_event': <function win32api.keybd_event>,
#   'mouse_event': <function win32api.mouse_event>,
#   'LoadCursor': <function win32api.LoadCursor>,
#   'LoadKeyboardLayout': <function win32api.LoadKeyboardLayout>,
#   'LoadLibrary': <function win32api.LoadLibrary>,
#   'LoadLibraryEx': <function win32api.LoadLibraryEx>,
#   'LoadResource': <function win32api.LoadResource>,
#   'LoadString': <function win32api.LoadString>,
#   'MapVirtualKey': <function win32api.MapVirtualKey>,
#   'MessageBeep': <function win32api.MessageBeep>,
#   'MessageBoxEx': <function win32api.MessageBoxEx>,
#   'MessageBox': <function win32api.MessageBox>,
#   'MonitorFromPoint': <function win32api.MonitorFromPoint>,
#   'MonitorFromRect': <function win32api.MonitorFromRect>,
#   'MonitorFromWindow': <function win32api.MonitorFromWindow>,
#   'MoveFile': <function win32api.MoveFile>,
#   'MoveFileEx': <function win32api.MoveFileEx>,
#   'OpenProcess': <function win32api.OpenProcess>,
#   'OpenThread': <function win32api.OpenThread>,
#   'OutputDebugString': <function win32api.OutputDebugString>,
#   'PostMessage': <function win32api.PostMessage>,
#   'PostQuitMessage': <function win32api.PostQuitMessage>,
#   'PostThreadMessage': <function win32api.PostThreadMessage>,
#   'RegCloseKey': <function win32api.RegCloseKey>,
#   'RegConnectRegistry': <function win32api.RegConnectRegistry>,
#   'RegCopyTree': <function win32api.RegCopyTree>,
#   'RegCreateKey': <function win32api.RegCreateKey>,
#   'RegCreateKeyEx': <function win32api.RegCreateKeyEx>,
#   'RegDeleteKey': <function win32api.RegDeleteKey>,
#   'RegDeleteKeyEx': <function win32api.RegDeleteKeyEx>,
#   'RegDeleteTree': <function win32api.RegDeleteTree>,
#   'RegDeleteValue': <function win32api.RegDeleteValue>,
#   'RegEnumKey': <function win32api.RegEnumKey>,
#   'RegEnumKeyEx': <function win32api.RegEnumKeyEx>,
#   'RegEnumKeyExW': <function win32api.RegEnumKeyExW>,
#   'RegEnumValue': <function win32api.RegEnumValue>,
#   'RegFlushKey': <function win32api.RegFlushKey>,
#   'RegGetKeySecurity': <function win32api.RegGetKeySecurity>,
#   'RegLoadKey': <function win32api.RegLoadKey>,
#   'RegOpenCurrentUser': <function win32api.RegOpenCurrentUser>,
#   'RegOpenKey': <function win32api.RegOpenKey>,
#   'RegOpenKeyEx': <function win32api.RegOpenKeyEx>,
#   'RegOpenKeyTransacted': <function win32api.RegOpenKeyTransacted>,
#   'RegOverridePredefKey': <function win32api.RegOverridePredefKey>,
#   'RegQueryValue': <function win32api.RegQueryValue>,
#   'RegQueryValueEx': <function win32api.RegQueryValueEx>,
#   'RegQueryInfoKey': <function win32api.RegQueryInfoKey>,
#   'RegQueryInfoKeyW': <function win32api.RegQueryInfoKeyW>,
#   'RegRestoreKey': <function win32api.RegRestoreKey>,
#   'RegSaveKey': <function win32api.RegSaveKey>,
#   'RegSaveKeyEx': <function win32api.RegSaveKeyEx>,
#   'RegSetKeySecurity': <function win32api.RegSetKeySecurity>,
#   'RegSetValue': <function win32api.RegSetValue>,
#   'RegSetValueEx': <function win32api.RegSetValueEx>,
#   'RegUnLoadKey': <function win32api.RegUnLoadKey>,
#   'RegisterWindowMessage': <function win32api.RegisterWindowMessage>,
#   'RegNotifyChangeKeyValue': <function win32api.RegNotifyChangeKeyValue>,
#   'SearchPath': <function win32api.SearchPath>,
#   'SendMessage': <function win32api.SendMessage>,
#   'SetConsoleCtrlHandler': <function win32api.SetConsoleCtrlHandler>,
#   'SetConsoleTitle': <function win32api.SetConsoleTitle>,
#   'SetCursorPos': <function win32api.SetCursorPos>,
#   'SetDllDirectory': <function win32api.SetDllDirectory>,
#   'SetErrorMode': <function win32api.SetErrorMode>,
#   'SetFileAttributes': <function win32api.SetFileAttributes>,
#   'SetLastError': <function win32api.SetLastError>,
#   'SetSysColors': <function win32api.SetSysColors>,
#   'SetLocalTime': <function win32api.SetLocalTime>,
#   'SetSystemTime': <function win32api.SetSystemTime>,
#   'SetClassLong': <function win32api.SetClassLong>,
#   'SetClassWord': <function win32api.SetClassWord>,
#   'SetCursor': <function win32api.SetCursor>,
#   'SetEnvironmentVariable': <function win32api.SetEnvironmentVariable>,
#   'SetEnvironmentVariableW': <function win32api.SetEnvironmentVariableW>,
#   'SetHandleInformation': <function win32api.SetHandleInformation>,
#   'SetStdHandle': <function win32api.SetStdHandle>,
#   'SetSystemPowerState': <function win32api.SetSystemPowerState>,
#   'SetThreadLocale': <function win32api.SetThreadLocale>,
#   'SetTimeZoneInformation': <function win32api.SetTimeZoneInformation>,
#   'SetWindowLong': <function win32api.SetWindowLong>,
#   'ShellExecute': <function win32api.ShellExecute>,
#   'ShowCursor': <function win32api.ShowCursor>,
#   'Sleep': <function win32api.Sleep>,
#   'SleepEx': <function win32api.SleepEx>,
#   'TerminateProcess': <function win32api.TerminateProcess>,
#   'ToAsciiEx': <function win32api.ToAsciiEx>,
#   'Unicode': <function win32api.Unicode>,
#   'UpdateResource': <function win32api.UpdateResource>,
#   'VkKeyScan': <function win32api.VkKeyScan>,
#   'VkKeyScanEx': <function win32api.VkKeyScanEx>,
#   'WinExec': <function win32api.WinExec>,
#   'WinHelp': <function win32api.WinHelp>,
#   'WriteProfileSection': <function win32api.WriteProfileSection>,
#   'WriteProfileVal': <function win32api.WriteProfileVal>,
#   'HIBYTE': <function win32api.HIBYTE>,
#   'LOBYTE': <function win32api.LOBYTE>,
#   'HIWORD': <function win32api.HIWORD>,
#   'LOWORD': <function win32api.LOWORD>,
#   'RGB': <function win32api.RGB>,
#   'MAKELANGID': <function win32api.MAKELANGID>,
#   'MAKEWORD': <function win32api.MAKEWORD>,
#   'MAKELONG': <function win32api.MAKELONG>,
#   'error': pywintypes.error,
#   'STD_INPUT_HANDLE': -10,
#   'STD_OUTPUT_HANDLE': -11,
#   'STD_ERROR_HANDLE': -12,
#   'PyDISPLAY_DEVICEType': PyDISPLAY_DEVICE,
#   'NameUnknown': 0,
#   'NameFullyQualifiedDN': 1,
#   'NameSamCompatible': 2,
#   'NameDisplay': 3,
#   'NameUniqueId': 6,
#   'NameCanonical': 7,
#   'NameUserPrincipal': 8,
#   'NameCanonicalEx': 9,
#   'NameServicePrincipal': 10,
#   'REG_NOTIFY_CHANGE_NAME': 1,
#   'REG_NOTIFY_CHANGE_ATTRIBUTES': 2,
#   'REG_NOTIFY_CHANGE_LAST_SET': 4,
#   'REG_NOTIFY_CHANGE_SECURITY': 8,
#   'VOS_DOS': 65536,
#   'VOS_NT': 262144,
#   'VOS__WINDOWS16': 1,
#   'VOS__WINDOWS32': 4,
#   'VOS_OS216': 131072,
#   'VOS_OS232': 196608,
#   'VOS__PM16': 2,
#   'VOS__PM32': 3,
#   'VOS_UNKNOWN': 0,
#   'VOS_DOS_WINDOWS16': 65537,
#   'VOS_DOS_WINDOWS32': 65540,
#   'VOS_NT_WINDOWS32': 262148,
#   'VOS_OS216_PM16': 131074,
#   'VOS_OS232_PM32': 196611,
#   'VFT_UNKNOWN': 0,
#   'VFT_APP': 1,
#   'VFT_DLL': 2,
#   'VFT_DRV': 3,
#   'VFT_FONT': 4,
#   'VFT_VXD': 5,
#   'VFT_STATIC_LIB': 7,
#   'VS_FF_DEBUG': 1,
#   'VS_FF_INFOINFERRED': 16,
#   'VS_FF_PATCHED': 4,
#   'VS_FF_PRERELEASE': 2,
#   'VS_FF_PRIVATEBUILD': 8,
#   'VS_FF_SPECIALBUILD': 32,
#   '__file__': 'c:\\users\\subhadeep banerjee\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\win32\\win32api.pyd'},
#  <function win32api.InitiateSystemShutdown>,
#  <function win32api.Apply>,
#  <function win32api.Beep>,
#  <function win32api.BeginUpdateResource>,
#  <function win32api.ChangeDisplaySettings>,
#  <function win32api.ChangeDisplaySettingsEx>,
#  <function win32api.ClipCursor>,
#  <function win32api.CloseHandle>,
#  <function win32api.CommandLineToArgv>,
#  <function win32api.CopyFile>,
#  <function win32api.DebugBreak>,
#  <function win32api.DeleteFile>,
#  <function win32api.DragQueryFile>,
#  <function win32api.DragFinish>,
#  <function win32api.DuplicateHandle>,
#  <function win32api.EndUpdateResource>,
#  ...]

# %% [markdown]
# ## gc.get_stats()
# Return a list of three per-generation dictionaries containing collection statistics since interpreter start. The number of keys may change in the future, but currently each dictionary will contain the following items:
#
# * collections is the number of times this generation was collected;
#
# * collected is the total number of objects collected inside this generation;
#
# * uncollectable is the total number of objects which were found to be uncollectable (and were therefore moved to the garbage list) inside this generation.

# %%
gc.get_stats()
# Out:
# [{'collections': 141, 'collected': 1887, 'uncollectable': 0},
#  {'collections': 12, 'collected': 96, 'uncollectable': 0},
#  {'collections': 1, 'collected': 0, 'uncollectable': 0}]

# %% [markdown]
# ## gc.set_threshold(threshold0[, threshold1[, threshold2]])
# Set the garbage collection thresholds (the collection frequency). Setting threshold0 to zero disables collection.
#
# The GC classifies objects into three generations depending on how many collection sweeps they have survived. New objects are placed in the youngest generation (generation 0). If an object survives a collection it is moved into the next older generation. Since generation 2 is the oldest generation, objects in that generation remain there after a collection. In order to decide when to run, the collector keeps track of the number object allocations and deallocations since the last collection. When the number of allocations minus the number of deallocations exceeds threshold0, collection starts. Initially only generation 0 is examined. If generation 0 has been examined more than threshold1 times since generation 1 has been examined, then generation 1 is examined as well. With the third generation, things are a bit more complicated, see Collecting the oldest generation for more information.

# %%
gc.set_threshold()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-016e36952464> in <module>
# ----> 1 gc.set_threshold()
#
# TypeError: set_threshold() takes at least 1 argument (0 given)

# %%
# Return the current collection counts as a tuple of (count0, count1, count2).
gc.get_count()
# Out:
# (58, 10, 1)

# %%
# Return the current collection thresholds as a tuple of (threshold0, threshold1, threshold2).
gc.get_threshold()
# Out:
# (700, 10, 10)

# %% [markdown]
# ## gc.get_referrers(*objs)
# Return the list of objects that directly refer to any of objs. This function will only locate those containers which support garbage collection; extension types which do refer to other objects but do not support garbage collection will not be found.
#
# Note that objects which have already been dereferenced, but which live in cycles and have not yet been collected by the garbage collector can be listed among the resulting referrers. To get only currently live objects, call collect() before calling get_referrers().
#
# Care must be taken when using objects returned by get_referrers() because some of them could still be under construction and hence in a temporarily invalid state. Avoid using get_referrers() for any purpose other than debugging.

# %% [markdown]
# ## gc.get_referents(*objs)
# Return a list of objects directly referred to by any of the arguments. The referents returned are those objects visited by the arguments’ C-level tp_traverse methods (if any), and may not be all objects actually directly reachable. tp_traverse methods are supported only by objects that support garbage collection, and are only required to visit objects that may be involved in a cycle. So, for example, if an integer is directly reachable from an argument, that integer object may or may not appear in the result list.

# %% [markdown]
# ## gc.is_tracked(obj)
# Returns True if the object is currently tracked by the garbage collector, False otherwise. As a general rule, instances of atomic types aren’t tracked and instances of non-atomic types (containers, user-defined objects…) are. However, some type-specific optimizations can be present in order to suppress the garbage collector footprint of simple instances (e.g. dicts containing only atomic keys and values):

# %%
gc.is_tracked(0)
# Out:
# False

# %%
gc.is_tracked("a")
# Out:
# False

# %%
gc.is_tracked([])
# Out:
# True

# %%
gc.is_tracked({})
# Out:
# False

# %%
gc.is_tracked('[<_ast.keyword at 0x1fa0868c5e0>]')
# Out:
# False

# %%
gc.is_tracked({"a": []})
# Out:
# True

# %%
gc.is_tracked({"a": 1})
# Out:
# False

# %%
# Returns True if the given object has been finalized by the garbage collector, False otherwise.
x = None
class Lazarus:
     def __del__(self):
            global x
            x = self
lazarus = Lazarus()
gc.is_finalized(lazarus)
del lazarus
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-f6ab9c12d4c2> in <module>
#       6             x = self
#       7 lazarus = Lazarus()
# ----> 8 gc.is_finalized(lazarus)
#       9 del lazarus
#
# AttributeError: module 'gc' has no attribute 'is_finalized'

# %% [markdown]
# ## gc.freeze()
# Freeze all the objects tracked by gc - move them to a permanent generation and ignore all the future collections. This can be used before a POSIX fork() call to make the gc copy-on-write friendly or to speed up collection. Also collection before a POSIX fork() call may free pages for future allocation which can cause copy-on-write too so it’s advised to disable gc in parent process and freeze before fork and enable gc in child process.

# %%
gc.freeze()

# %%
gc.collect()
# Out:
# 30

# %%
# Unfreeze the objects in the permanent generation, put them back into the oldest generation.
gc.unfreeze()

# %%
# Return the number of objects in the permanent generation.
gc.get_freeze_count()
# Out:
# 52946

# %% [markdown]
# # The following variables are provided for read-only access (you can mutate the values but should not rebind them):

# %% [markdown]
# ## gc.garbage
# A list of objects which the collector found to be unreachable but could not be freed (uncollectable objects). Starting with Python 3.4, this list should be empty most of the time, except when using instances of C extension types with a non-NULL tp_del slot.
#
# If DEBUG_SAVEALL is set, then all unreachable objects will be added to this list rather than freed.
#
# Changed in version 3.2: If this list is non-empty at interpreter shutdown, a ResourceWarning is emitted, which is silent by default. If DEBUG_UNCOLLECTABLE is set, in addition all uncollectable objects are printed.
#
# Changed in version 3.4: Following PEP 442, objects with a __del__() method don’t end up in gc.garbage anymore.

# %% [markdown]
# ## gc.callbacks
# A list of callbacks that will be invoked by the garbage collector before and after collection. The callbacks will be called with two arguments, phase and info.
#
# phase can be one of two values:
#
# * “start”: The garbage collection is about to start.
#
# * “stop”: The garbage collection has finished.
#
# info is a dict providing more information for the callback. The following keys are currently defined:
#
# * “generation”: The oldest generation being collected.
#
# * “collected”: When phase is “stop”, the number of objects successfully collected.
#
# * “uncollectable”: When phase is “stop”, the number of objects that could not be collected and were put in garbage.
#
# Applications can add their own callbacks to this list. The primary use cases are:
#
# * Gathering statistics about garbage collection, such as how often various generations are collected, and how long the collection takes.
#
# * Allowing applications to identify and clear their own uncollectable types when they appear in garbage.

# %% [markdown]
# # The following constants are provided for use with set_debug():

# %% [markdown]
# ## gc.DEBUG_STATS
# Print statistics during collection. This information can be useful when tuning the collection frequency.
#
# ## gc.DEBUG_COLLECTABLE
# Print information on collectable objects found.
#
# ## gc.DEBUG_UNCOLLECTABLE
# Print information of uncollectable objects found (objects which are not reachable but cannot be freed by the collector). These objects will be added to the garbage list.
#
# Changed in version 3.2: Also print the contents of the garbage list at interpreter shutdown, if it isn’t empty.
#
# ## gc.DEBUG_SAVEALL
# When set, all unreachable objects found will be appended to garbage rather than being freed. This can be useful for debugging a leaking program.
#
# ## gc.DEBUG_LEAK
# The debugging flags necessary for the collector to print information about a leaking program (equal to DEBUG_COLLECTABLE | DEBUG_UNCOLLECTABLE | DEBUG_SAVEALL).
